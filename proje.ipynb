# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Abdul Ghani Khan**
# Currently I am a student

# %% [markdown]
# *I am interested in data science because i like to work with data*

# %% [markdown]
# ### The following code will add two numbers

# %%
num1 = 2.5
num2 = 3.5

sum = num1 + num2

print('The sum of {0} and {1} is {2}'.format(num1,num2,sum))
# Out:
# The sum of 2.5 and 3.5 is 6.0

# %% [markdown]
# This is the `code` and `syntax` highlighting
#
# >This is the example of blocked quotes
#
# ..* Link test
